# %%
# 🔧 기본 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl

# ✅ 한글 정렬, 너비 확장, 행/열 표시 전부 자동화
pd.set_option('display.unicode.east_asian_width', True)  # 한글 정렬 맞추기
pd.set_option('display.width', 150)                      # 콘솔 너비 자동 확장
pd.set_option('display.max_columns', None)               # 모든 열 표시
pd.set_option('display.max_rows', 1000)                  # 최대 1000행 표시
pd.set_option('display.max_colwidth', None)              # 긴 문자열 자르지 않기
pd.set_option('display.expand_frame_repr', False)

# ✅ matplotlib 시각화 설정 (한글 & 마이너스 깨짐 방지)
plt.rcParams['font.family'] = 'Malgun Gothic'             # 윈도우용 한글 폰트
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 파일 저장 및 열기
# DataFrame 객체를 excel,csv,txt 등 형태의 파일로 저장 및 열기

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}
df=pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name='지원번호'
df
# Out:
#             이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 지원번호
# 1번       채치수  북산고  197    90    85   100    95    85      Python
# 2번       정대만  북산고  184    40    35    50    55    25        Java
# 3번       송태섭  북산고  168    80    75    70    80    75  Javascript
# 4번       서태웅  북산고  187    40    60    70    75    80
# 5번       강백호  북산고  188    15    20    10    35    10
# 6번       변덕규  능남고  202    80   100    95    85    80           C
# 7번       황태산  능남고  188    55    65    45    40    35      PYTHON
# 8번       윤대협  능남고  190   100    85    90    95    95          C#

# %% [markdown]
# ## 저장하기
# ### csv파일로 저장

# %%
df.to_csv('score.csv',encoding='utf-8-sig')  #df를 csv로저장

# %%
df.to_csv('score2.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# ### txt로 저장

# %%
df.to_csv('score.txt',sep='\t')  #tab으로 구분된 텍스트파일

# %% [markdown]
# ### 엑셀파일로 저장

# %%
df.to_excel('score.xlsx')

# %% [markdown]
# ## 열기

# %% [markdown]
# ### csv 파일 열기

# %%
df=pd.read_csv('score2.csv')
df
# Out:
#      이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 0  채치수  북산고  197    90    85   100    95    85      Python
# 1  정대만  북산고  184    40    35    50    55    25        Java
# 2  송태섭  북산고  168    80    75    70    80    75  Javascript
# 3  서태웅  북산고  187    40    60    70    75    80         NaN
# 4  강백호  북산고  188    15    20    10    35    10         NaN
# 5  변덕규  능남고  202    80   100    95    85    80           C
# 6  황태산  능남고  188    55    65    45    40    35      PYTHON
# 7  윤대협  능남고  190   100    85    90    95    95          C#

# %%
df=pd.read_csv('score.csv',skiprows=2)   #skiprow에 지정된 개수만큼의 row를 건너뛴다.
df
# Out:
#    2번  정대만  북산고  184   40   35  50  55  25        Java
# 0  3번  송태섭  북산고  168   80   75  70  80  75  Javascript
# 1  4번  서태웅  북산고  187   40   60  70  75  80         NaN
# 2  5번  강백호  북산고  188   15   20  10  35  10         NaN
# 3  6번  변덕규  능남고  202   80  100  95  85  80           C
# 4  7번  황태산  능남고  188   55   65  45  40  35      PYTHON
# 5  8번  윤대협  능남고  190  100   85  90  95  95          C#

# %%
df=pd.read_csv('score.csv',skiprows=[1,3,5])   #skiprow리스트내에 지정된 raw를 건너뛴다
df
# Out:
#   지원번호    이름    학교   키  국어  영어  수학  과학  사회  SW특기
# 0      2번  정대만  북산고  184    40    35    50    55    25    Java
# 1      4번  서태웅  북산고  187    40    60    70    75    80     NaN
# 2      6번  변덕규  능남고  202    80   100    95    85    80       C
# 3      7번  황태산  능남고  188    55    65    45    40    35  PYTHON
# 4      8번  윤대협  능남고  190   100    85    90    95    95      C#

# %%
df=pd.read_csv('score.csv',nrows=4)  #지정된개수의 row만 불러온다.
df
# Out:
#   지원번호    이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 0      1번  채치수  북산고  197    90    85   100    95    85      Python
# 1      2번  정대만  북산고  184    40    35    50    55    25        Java
# 2      3번  송태섭  북산고  168    80    75    70    80    75  Javascript
# 3      4번  서태웅  북산고  187    40    60    70    75    80         NaN

# %%
df=pd.read_csv('score.csv',skiprows=[1,2],nrows=4) #처음 2row무시,그다음 4row를 가져옴.
df
# Out:
#   지원번호    이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 0      3번  송태섭  북산고  168    80    75    70    80    75  Javascript
# 1      4번  서태웅  북산고  187    40    60    70    75    80         NaN
# 2      5번  강백호  북산고  188    15    20    10    35    10         NaN
# 3      6번  변덕규  능남고  202    80   100    95    85    80           C

# %% [markdown]
# ### txt파일열기

# %%
df=pd.read_csv('score.txt',sep='\t')  #sep='\t'는 txt저장할때 꼭 set로 챙겨주자
df
# Out:
#   지원번호    이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 0      1번  채치수  북산고  197    90    85   100    95    85      Python
# 1      2번  정대만  북산고  184    40    35    50    55    25        Java
# 2      3번  송태섭  북산고  168    80    75    70    80    75  Javascript
# 3      4번  서태웅  북산고  187    40    60    70    75    80         NaN
# 4      5번  강백호  북산고  188    15    20    10    35    10         NaN
# 5      6번  변덕규  능남고  202    80   100    95    85    80           C
# 6      7번  황태산  능남고  188    55    65    45    40    35      PYTHON
# 7      8번  윤대협  능남고  190   100    85    90    95    95          C#

# %%
df=pd.read_csv('score.txt',sep='\t')
df.set_index('지원번호',inplace=True)
df
# Out:
#             이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 지원번호
# 1번       채치수  북산고  197    90    85   100    95    85      Python
# 2번       정대만  북산고  184    40    35    50    55    25        Java
# 3번       송태섭  북산고  168    80    75    70    80    75  Javascript
# 4번       서태웅  북산고  187    40    60    70    75    80         NaN
# 5번       강백호  북산고  188    15    20    10    35    10         NaN
# 6번       변덕규  능남고  202    80   100    95    85    80           C
# 7번       황태산  능남고  188    55    65    45    40    35      PYTHON
# 8번       윤대협  능남고  190   100    85    90    95    95          C#

# %% [markdown]
# ### 엑셀파일 열기

# %%
df=pd.read_excel('score.xlsx',index_col='지원번호')
df
# Out:
#             이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 지원번호
# 1번       채치수  북산고  197    90    85   100    95    85      Python
# 2번       정대만  북산고  184    40    35    50    55    25        Java
# 3번       송태섭  북산고  168    80    75    70    80    75  Javascript
# 4번       서태웅  북산고  187    40    60    70    75    80         NaN
# 5번       강백호  북산고  188    15    20    10    35    10         NaN
# 6번       변덕규  능남고  202    80   100    95    85    80           C
# 7번       황태산  능남고  188    55    65    45    40    35      PYTHON
# 8번       윤대협  능남고  190   100    85    90    95    95          C#
