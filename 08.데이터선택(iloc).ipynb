# %%
# 🔧 기본 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl

# ✅ 한글 정렬, 너비 확장, 행/열 표시 전부 자동화
pd.set_option('display.unicode.east_asian_width', True)  # 한글 정렬 맞추기
pd.set_option('display.width', 150)                      # 콘솔 너비 자동 확장
pd.set_option('display.max_columns', None)               # 모든 열 표시
pd.set_option('display.max_rows', 1000)                  # 최대 1000행 표시
pd.set_option('display.max_colwidth', None)              # 긴 문자열 자르지 않기
pd.set_option('display.expand_frame_repr', False)

# ✅ matplotlib 시각화 설정 (한글 & 마이너스 깨짐 방지)
plt.rcParams['font.family'] = 'Malgun Gothic'             # 윈도우용 한글 폰트
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 데이터선택(iloc)
# 위치(정수값)를 이용하여 원하는 row에서 원하는 col을 선택

# %%
df=pd.read_excel('score.xlsx',index_col='지원번호')
df
# Out:
#             이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 지원번호
# 1번       채치수  북산고  197    90    85   100    95    85      Python
# 2번       정대만  북산고  184    40    35    50    55    25        Java
# 3번       송태섭  북산고  168    80    75    70    80    75  Javascript
# 4번       서태웅  북산고  187    40    60    70    75    80         NaN
# 5번       강백호  북산고  188    15    20    10    35    10         NaN
# 6번       변덕규  능남고  202    80   100    95    85    80           C
# 7번       황태산  능남고  188    55    65    45    40    35      PYTHON
# 8번       윤대협  능남고  190   100    85    90    95    95          C#

# %%
df.iloc[0]   #0번 인덱스 가져오기.   위치로 가져오는 거기 때문에 index의 이름이 아닌 정수값을 넣는다
# Out:
# 이름      채치수
# 학교      북산고
# 키           197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 1번, dtype: object

# %%
df.iloc[0:5]
# Out:
#             이름    학교   키  국어  영어  수학  과학  사회      SW특기
# 지원번호
# 1번       채치수  북산고  197    90    85   100    95    85      Python
# 2번       정대만  북산고  184    40    35    50    55    25        Java
# 3번       송태섭  북산고  168    80    75    70    80    75  Javascript
# 4번       서태웅  북산고  187    40    60    70    75    80         NaN
# 5번       강백호  북산고  188    15    20    10    35    10         NaN

# %%
df.iloc[0,1]    #0번째row,1번째col 을 가져옴.
# Out:
# '북산고'

# %%
df.iloc[[1,2],[2]]
# Out:
#            키
# 지원번호
# 2번       184
# 3번       168

# %%
# 아하 loc와 iloc의 차이는 이름으로 불러오냐 위치값으로 불러오냐의 차이밖에없구나

# %%
df.iloc[0:5,3:8]
# Out:
#           국어  영어  수학  과학  사회
# 지원번호
# 1번         90    85   100    95    85
# 2번         40    35    50    55    25
# 3번         80    75    70    80    75
# 4번         40    60    70    75    80
# 5번         15    20    10    35    10
